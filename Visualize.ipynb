# %%
import os

# %%
import tensorflow as tf

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ### DENSE MODEL

# %% [markdown]
# ### After attacks

# %%
#default, fgsm, bim, onestepless,
densem_att = [0.98, 0.66,0.52, 0.51]

# %%
colors_0=['blue', 'red', 'orange', 'yellow']
index_0 = ['default acc', 'fgsm', 'bim', '1step']

# %%
plt.bar(index_0, height=densem_att, width=0.3, color=colors_0)
plt.grid(color='gray', linewidth=0.7, axis='both', alpha=0.3)
plt.xlabel('attacks')
plt.ylabel('model_acc')
plt.title('Acc of Dense Model after attacks', fontsize=20, y=1.1)
#plt.axhline(y=0.65, color='green', linestyle='--', label='after autoenc clean')
#plt.show()
plt.legend(loc='lower right')
plt.savefig('DENSEM_ACC_ATTACK.png',bbox_inches='tight')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#RUSSIAN
colors_0=['blue', 'red', 'orange', 'yellow']
index_0 = ['без атак', 'fgsm', 'bim', '1step']
plt.bar(index_0, height=densem_att, width=0.3, color=colors_0)
plt.grid(color='gray', linewidth=0.7, axis='both', alpha=0.3)
plt.xlabel('атаки')
plt.ylabel('точность модели')
plt.title('Точность полносвязной модели до и после атак', fontsize=20, y=1.1)
#plt.axhline(y=0.65, color='green', linestyle='--', label='after autoenc clean')
#plt.show()
plt.legend(loc='lower right')
plt.savefig('DENSEM_ACC_ATTACK_РУС.png',bbox_inches='tight')
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### After Dense autoenc

# %%
#dense model_dense_autoenc
#default, fgsm, bim, onestepless, after autoenc fgsm,bim,onestepless, eps = 0.1
dense_m_auto_d = [0.98, 0.66, 0.52, 0.51,  0.81, 0.82, 0.79]

# %%
colors_dd=['blue', 'red', 'orange', 'yellow','red', 'orange', 'yellow']

# %%
index_dd = ['default acc', 'fgsm', 'bim', '1step', 'fgsm_aut', 'bim_aut', ' 1step_aut']

# %%
plt.bar(index_dd, height=dense_m_auto_d, width=0.5, color=colors_dd)
plt.grid(color='gray', linewidth=0.7, axis='both', alpha=0.3)
plt.xlabel('attacks')
plt.ylabel('model_acc')
plt.title('Acc of Dense Model + Dense Autoenc', fontsize=20, y=1.1)
plt.axvline(x=3.5, color='green', linestyle='--', label='after autoenc clean')
#plt.show()
plt.legend(loc='lower right')
plt.savefig('DENSE_MODEL_DENSE_AUTOENC.png',bbox_inches='tight')

# %%
index_dd2 = ['без атак', 'fgsm', 'bim', '1step', 'fgsm_aut', 'bim_aut', ' 1step_aut']

# %%
#RUSSIAN
plt.bar(index_dd2, height=dense_m_auto_d, width=0.5, color=colors_dd)
plt.grid(color='gray', linewidth=0.7, axis='both', alpha=0.3)
plt.xlabel('атаки')
plt.ylabel('точность исх. модели')
plt.title('Точность Полносвязной модели + Полносвязный Автоенкодер', fontsize=20, y=1.1)
plt.axvline(x=3.5, color='green', linestyle='--', label='с исп. автоенкодера')
#plt.show()
plt.legend(loc='lower right')
plt.savefig('DENSE_MODEL_ACC_РУС.png',bbox_inches='tight')

# %% [markdown]
# ### After conv autoencoder

# %%
#dense model_dense_autoenc
#default, fgsm, bim, onestepless, after autoenc fgsm,bim,onestepless, eps = 0.1
dense_m_auto_c = [0.98, 0.66, 0.52, 0.51,  0.68, 0.80, 0.71] 
colors_dc=['blue', 'red', 'orange', 'yellow','red', 'orange', 'yellow']
index_dc = ['default acc', 'fgsm', 'bim', '1step', 'fgsm_aut', 'bim_aut', ' 1step_aut']

# %%
plt.bar(index_dc, height=dense_m_auto_c, width=0.5, color=colors_dc)
plt.grid(color='gray', linewidth=0.7, axis='both', alpha=0.3)
plt.xlabel('attacks')
plt.ylabel('model_acc')
plt.title('Acc of Dense Model + Conv Autoenc', fontsize=20, y=1.1)
plt.axvline(x=3.5, color='green', linestyle='--', label='after autoenc clean')
#plt.show()
plt.legend(loc='lower right')
plt.savefig('DENSE_MODEL_CONV_AUTOENC.png',bbox_inches='tight')

# %%
index_dc2 = ['без атак', 'fgsm', 'bim', '1step', 'fgsm_aut', 'bim_aut', ' 1step_aut']

# %%
#RUSSIAN
plt.bar(index_dc2, height=dense_m_auto_c, width=0.5, color=colors_dc)
plt.grid(color='gray', linewidth=0.7, axis='both', alpha=0.3)
plt.xlabel('атаки')
plt.ylabel('точность исх. модели')
plt.title('Точность Полносвязной модели + Сверточный Автоенкодер', fontsize=20, y=1.1)
plt.axvline(x=3.5, color='green', linestyle='--', label='с исп. автоенкодера')
#plt.show()
plt.legend(loc='lower right')
plt.savefig('DENSE_MODEL_CONV_AUTOENC_РУС.png',bbox_inches='tight')

# %% [markdown]
# ## Conv Model

# %% [markdown]
# ### After Attacks

# %%
#default, fgsm, bim, onestepless, eps=0.3 !!!!
convm_att = [0.99, 0.51, 0.49, 0.45]

# %%
colors_1=['blue', 'red', 'orange', 'yellow']
index_1 = ['default acc', 'fgsm', 'bim', '1step']

# %%
plt.bar(index_1, height=convm_att, width=0.3, color=colors_1)
plt.grid(color='gray', linewidth=0.7, axis='both', alpha=0.3)
plt.xlabel('attacks')
plt.ylabel('model_acc')
plt.title('Acc of Conv Model after attacks', fontsize=20, y=1.1)
#plt.axhline(y=0.65, color='green', linestyle='--', label='after autoenc clean')
#plt.show()
plt.legend(loc='lower right')
plt.savefig('CONVM_ACC_ATTACK.png',bbox_inches='tight')
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#RUSSIAN
colors_1=['blue', 'red', 'orange', 'yellow']
index_1 = ['без атак', 'fgsm', 'bim', '1step']
plt.bar(index_0, height=convm_att, width=0.3, color=colors_1)
plt.grid(color='gray', linewidth=0.7, axis='both', alpha=0.3)
plt.xlabel('атаки')
plt.ylabel('точность модели')
plt.title('Точность сверточной модели до и после атак', fontsize=20, y=1.1)
#plt.axhline(y=0.65, color='green', linestyle='--', label='after autoenc clean')
#plt.show()
plt.legend(loc='lower right')
plt.savefig('CONVM_ACC_ATTACK_РУС.png',bbox_inches='tight')
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### After Dense Autoencoder

# %%
#conv model_dense_autoenc
conv_m_auto_d = [0.99, 0.51, 0.49, 0.45, 0.76, 0.82, 0.87] 
#default, fgsm, bim, onestepless, after autoenc fgsm,bim,onestepless, eps = 0.1, eps_bim=1.0
colors=['blue', 'red', 'orange', 'yellow','red', 'orange', 'yellow']
index_cd = ['default', 'fgsm', 'bim', '1step', 'fgsm_aut', 'bim_aut', '1step_aut']
index_cd2 = ['без атак', 'fgsm', 'bim', '1step', 'fgsm_aut', 'bim_aut', '1step_aut']
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 641

# %%
plt.bar(index_cd, height=conv_m_auto_d, width=0.5, color=colors)
plt.grid(color='gray', linewidth=0.7, axis='both', alpha=0.3)
plt.xlabel('attacks')
plt.ylabel('model_acc')
plt.title('Acc of Conv Model + Dense Autoenc', fontsize=20, y=1.1)
plt.axvline(x=3.5, color='green', linestyle='--', label='after autoenc clean')
#plt.show()
plt.legend(loc='lower right')
plt.savefig('CONV_MODEL_DENSE_AUTOENC.png',bbox_inches='tight')

# %%
#RUSSIAN
plt.bar(index_cd2, height=conv_m_auto_d, width=0.5, color=colors)
plt.grid(color='gray', linewidth=0.7, axis='both', alpha=0.3)
plt.xlabel('атаки')
plt.ylabel('точность исх. модели')
plt.title('Точность Сверточной модели + Полносвязный Автоенкодер', fontsize=20, y=1.1)
plt.axvline(x=3.5, color='green', linestyle='--', label='с исп. автоенкодера')
#plt.show()
plt.legend(loc='lower right')
plt.savefig('CONV_MODEL_DENSE_AUTOENC_РУС.png',bbox_inches='tight')

# %% [markdown]
# ### After Conv Autoencoder

# %%
#conv model_conv_autoenc

# %%
#conv model_conv_autoenc
conv_m_auto_c = [0.99, 0.51, 0.49, 0.45, 0.65, 0.60, 0.71] 
#default, fgsm, bim, onestepless, after autoenc fgsm,bim,onestepless, eps = 0.1, eps_bim=1.0
colors=['blue', 'red', 'orange', 'yellow','red', 'orange', 'yellow']
index_cc = ['default', 'fgsm', 'bim', '1step', 'fgsm_aut', 'bim_aut', '1step_aut']
index_cc2 = ['без атак', 'fgsm', 'bim', '1step', 'fgsm_aut', 'bim_aut', '1step_aut']

# %%
plt.bar(index_cc, height=conv_m_auto_c, width=0.5, color=colors)
plt.grid(color='gray', linewidth=0.7, axis='both', alpha=0.3)
plt.xlabel('attacks')
plt.ylabel('model_acc')
plt.title('Acc of Conv Model + Conv Autoenc', fontsize=20, y=1.1)
plt.axvline(x=3.5, color='green', linestyle='--', label='after autoenc clean')
#plt.show()
plt.legend(loc='lower right')
plt.savefig('CONV_MODEL_CONC_AUTOENC.png',bbox_inches='tight')

# %%
#RUSSIAN
plt.bar(index_cc2, height=conv_m_auto_c, width=0.5, color=colors)
plt.grid(color='gray', linewidth=0.7, axis='both', alpha=0.3)
plt.xlabel('атаки')
plt.ylabel('точность исх. модели')
plt.title('Точность Сверточной модели + Сверточный Автоенкодер', fontsize=20, y=1.1)
plt.axvline(x=3.5, color='green', linestyle='--', label='с исп. автоенкодера')
#plt.show()
plt.legend(loc='lower right')
plt.savefig('CONV_MODEL_CONV_AUTOENC_РУС.png',bbox_inches='tight')

# %% [markdown]
# ### COMPARING AUTOENC WORK ON DIFFERENT EPSILONS

# %% [markdown]
# ### 1step att Dense model dense+conv ---- DenConv se model dense+conv eps= 0.4

# %%
#conv model_conv_autoenc
overall = [0.41, 0.66, 0.65, 0.43, 0.72, 0.6] 
#default, fgsm, bim, onestepless, after autoenc fgsm,bim,onestepless, eps = 0.1, eps_bim=1.0
colors=['blue', 'red', 'orange', 'green', 'black', 'yellow']
index_1st = ['after 1st attack', 'dense auenc', 'conv auenc','after 1st attack2', 'dense auenc2', 'conv auenc2']

# %%
#default models acc 0,98 and 0,99
#DENSE MODEL
densem = [0.41, 0.66, 0.65] # after 1step, after dense enc, after conv enc
colors_1st=['y','c','m', 'b','g','b']
index_1st = ['no enc', 'dense enc', 'conv enc','no enc', 'dense enc', 'conv enc']
#index_2_1st = ['после 1st', 'dense autoenc', 'conv autoenc']
#index_1st =[1,2,3,4,5,6]

# %%
convm = [0.43, 0.72, 0.60] # after bim, after dense enc, after conv enc

# %%
overall = densem+convm
overall
# Out:
# [0.41, 0.66, 0.65, 0.43, 0.72, 0.6]

# %%
plt.bar(index_1st, height=overall, width=0.3, color=colors)
plt.grid(color='gray', linewidth=0.7, axis='both', alpha=0.3)
plt.xlabel('models')
plt.ylabel('model_acc')
plt.title('Dense Model    Conv Model', fontsize=20, y=1.1)
plt.axvline(x=3.5, color='red', linestyle='--', label='another model')
plt.show()
#plt.legend(loc='lower right')
plt.savefig('COMPARE_1st_DC_MODELS.png',bbox_inches='tight')

# %%
densem+convm
# Out:
# [0.41, 0.66, 0.65, 0.43, 0.72, 0.6]

# %%
#DataFrame
import pandas as pd

# %%
dense_acc = [0.41, 0.66, 0.65]
conv_acc = [0.43, 0.72, 0.6]
index = ['after 1st', 'dense autoenc', 'conv autoenc']

df = pd.DataFrame({'Dense model' : dense_acc,
                  'Conv model' : conv_acc}, index=index)
ax = df.plot.bar(color={'Dense model':'blue' , 'Conv model':'deeppink'}, width=0.3)
plt.title('Model Accuracy after attack and after autoencoders', fontsize=15, y=1.05)

#plt.grid(color='gray', linewidth=0.7, axis='both', alpha=0.3)

plt.savefig('COMPARE_1st_DC_MODELS_2.png',bbox_inches='tight')

# %%
#RUSSIAN
dense_acc = [0.41, 0.66, 0.65]
conv_acc = [0.43, 0.72, 0.6]
index = ['после атаки 1st', 'dense автоен-р', 'conv автоен-р']

df = pd.DataFrame({'Dense модель' : dense_acc,
                  'Conv модель' : conv_acc}, index=index)

plt.figure()
plt.rcParams.update({'font.size': 15})
ax = df.plot.bar(color={'Dense модель':'blue' , 'Conv модель':'deeppink'}, width=0.3, figsize=(10,6))
#ax.set_fontsize(10)
plt.title('Точность моделей после атаки OneStepLeastLikely до и после использования автоен-ов', fontsize=20, y=1.05)
plt.xlabel('события')
plt.ylabel('точность')
plt.grid(color='gray', linewidth=0.7, axis='both', alpha=0.3)

plt.savefig('COMPARE_1st_DC_MODELS_2_РУС.png',bbox_inches='tight')
